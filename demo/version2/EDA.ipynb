# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
file_path = 'synthetic_data_v2.csv'
df = pd.read_csv(file_path)

# %%
print("Dataset Head:")
print(df.head())
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Head:
#          Name  Age  Job_switches                   Career  Education  \
# 0  bYjdDCoEfw   21             1            Web developer        PhD
# 1  cRWKwUqwGd   35             5  Senior Systems Engineer    Masters
# 2  IaXcUljgva   37             0            Web developer  Bachelors
# 3  cqCOxdWrlA   40             3        Software Engineer    Masters
# 4  ENRmsYuVXC   60             4           Data Scientist    Masters
#
#    Experience
# 0          29
# 1          23
# 2          29
# 3           4
# 4          20
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600 entries, 0 to 1599
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          1600 non-null   object
#  1   Age           1600 non-null   int64
#  2   Job_switches  1600 non-null   int64
#  3   Career        1600 non-null   object
#  4   Education     1600 non-null   object
# ...

# %%
sns.pairplot(df, diag_kind='kde')
plt.show()
